# %%
kendaraan = ['Vesmet', 'Sepeda Motor', 120, 'Biru', 2]
print("kendaraan saya")
print(kendaraan)
print("========")
kendaraan.extend([45000000, "Metic"])
print(kendaraan)
print("========")
kendaraan.insert(2, 'Vesmet')
print(kendaraan)
print("========")
# Out:
# kendaraan saya
# ['Vesmet', 'Sepeda Motor', 120, 'Biru', 2]
# ...
# ['Vesmet', 'Sepeda Motor', 120, 'Biru', 2, 45000000, 'Metic']
# ...
# ['Vesmet', 'Sepeda Motor', 'Vesmet', 120, 'Biru', 2, 45000000, 'Metic']
# ...

# %%
print('Ini adalah program sederhana untuk menghitung luas bangun datar')
print("Pilih Menu angka 1-3 : \n1. Persegi\n2. Lingkaran\n3. Segitiga")
pilihMenu = int(input("Silahkan pilih menu dengan mengetikan angka 1-3 : "))
match pilihMenu:
    case 1:
         print("Ini adalah memu untuk menghitung luas persegi")
         sisi = int(input("Silahkan masukan nilai yang mau dihitung"))
         hitung = 2 * 4
         print(f"Luas persegi adalah : {hitung}")
    case 2:
         print("Ini adalah menu untuk menghitung luas lingkaran")
         r = int(input("Silahkan masukan nilai yang mau dihitung"))
         hitung = 22/7 * r * r
         print(f"Luas lingkarang adalah : {hitung}")
    case 3:
         print ("Ini adalah menu untuk menghitung luas segitiga")
         alas = int(input("Silahkan masukan nilai yang mau dihitung"))
         hitung = 2/7 * a * t
         print(f"Luas segitiga adalah : {hitung}")
    case _:
         print("Pilihan tidak valid, silahkan pilih antar 1-3")
# Out:
# Ini adalah program sederhana untuk menghitung luas bangun datar
# Pilih Menu angka 1-3 :
# 1. Persegi
# 2. Lingkaran
# 3. Segitiga
# Silahkan pilih menu dengan mengetikan angka 1-3 : 2
# Ini adalah menu untuk menghitung luas lingkaran
# Silahkan masukan nilai yang mau dihitung14
# Luas lingkarang adalah : 616.0
